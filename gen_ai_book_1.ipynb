# %% [markdown]
# <a href="https://colab.research.google.com/github/shiftkey-labs/GenAI-Course/blob/main/gen_ai_book_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to ShiftKey's Gen AI Certificate
# ## This is a nb

# %%
# !pip install huggingface_hub

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     A token is already saved on your machine. Run `huggingface-cli whoami` to get more information or `huggingface-cli logout` if you want to log out.
#     Setting a new token will erase the existing one.
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) n
# ...

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("openai-community/gpt2")
model = AutoModelForCausalLM.from_pretrained("openai-community/gpt2")
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
input_text = """
Tell me about the history of Germany
"""

# Create a prompt to encourage summarization
input_prompt = f"{input_text}"

# Tokenize the input prompt
input_ids = tokenizer.encode(input_prompt, return_tensors='pt')

# Generate the summary with adjusted parameters
output = model.generate(
    input_ids,
    max_length=150,
    num_return_sequences=1,
    no_repeat_ngram_size=2,
    temperature=0.7,
    top_p=0.9,
    top_k=50,
    early_stopping=True
)

# Decode the generated tokens back to text
summary = tokenizer.decode(output[0], skip_special_tokens=True)



print("Summary:", summary)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Summary:
# Tell me about the history of Germany
#
# I am a German, and I am very proud of my country. I have always been a strong supporter of the German people.
# ...
#  (The German Chancellor)
# , I think that the Germans are very strong. They are strong because they are the strongest country in the world. We are not weak because we are weak. The Germans have a great deal of experience in this field. And they have been very successful in their efforts. But they also have great experience with the other countries. So, they know that they can do things better than we do. That is why they want to do better. It is because of their experience that we have achieved great things. In the

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("google/flan-t5-small")
model = AutoModelForSeq2SeqLM.from_pretrained("google/flan-t5-small")
# Out:
# tokenizer_config.json:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.40k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/308M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]

# %%
# Initialize the tokenizer and model
tokenizer = AutoTokenizer.from_pretrained("google/flan-t5-small")
model = AutoModelForSeq2SeqLM.from_pretrained("google/flan-t5-small")

# Define your input text that needs to be summarized
input_text = """
OpenAI is a research organization that aims to develop and direct artificial intelligence (AI) in a way that benefits humanity as a whole. OpenAI was founded in December 2015, with Elon Musk, Sam Altman, and other investors pledging over $1 billion. The organization is known for its work in advancing the field of AI, including the development of powerful language models like GPT-3.
"""

# Prepend the task description to the input text
input_prompt = f"summarize: {input_text}"

# Tokenize the input prompt
input_ids = tokenizer(input_prompt, return_tensors='pt').input_ids

# Generate the summary
output_ids = model.generate(input_ids, max_length=100, num_beams=4, early_stopping=True)

# Decode the generated tokens back to text
summary = tokenizer.decode(output_ids[0], skip_special_tokens=True)

print("Summary:", summary)
# Out:
# Summary: OpenAI is a research organization that aims to develop and direct artificial intelligence (AI) in a way that benefits humanity as a whole.
